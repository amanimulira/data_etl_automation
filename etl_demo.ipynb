# %% [markdown]
# # ETL Demo Notebook
#
# This notebook demonstrates the ingestion of AdventureWorks (SQL Server) and Azure Open Datasets (weather/demographics), cleaning, and producing an analytics-ready CSV. Fill `.env` and ensure SQL Server is reachable.
#
# **Run order:** 1) Configure `.env` 2) Start SQL Server (docker or local) 3) Place AdventureWorks DB or use existing DB 4) Run cells.

# %%
from dotenv import load_dotenv
load_dotenv()
print('Loaded env vars from .env')
# Out:
# Loaded env vars from .env

# %%
# Install dependencies (uncomment if needed)
# !pip3.11 install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.0.42)
# Requirement already satisfied: pyodbc in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (5.2.0)
# Requirement already satisfied: psycopg2-binary in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.9.10)
# Requirement already satisfied: azure-storage-blob in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (12.26.0)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: nbformat in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: jupyterlab in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (4.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sqlalchemy->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: azure-core>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-storage-blob->-r requirements.txt (line 5)) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-storage-blob->-r requirements.txt (line 5)) (45.0.6)
# Requirement already satisfied: isodate>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-storage-blob->-r requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 7)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 7)) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 7)) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: async-lru>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyterlab->-r requirements.txt (line 8)) (6.17.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (2.2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (0.2.4)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 8)) (67.6.0)
# Requirement already satisfied: tornado>=6.2.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyterlab->-r requirements.txt (line 8)) (6.2)
# Requirement already satisfied: anyio>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (7.4.7)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (7.16.6)
# Requirement already satisfied: overrides>=5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: pyzmq>=24 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: requests>=2.31 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: six>=1.11.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from azure-core>=1.30.0->azure-storage-blob->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: cffi>=1.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cryptography>=2.1.4->azure-storage-blob->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 8)) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: appnope in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (1.5.6)
# Requirement already satisfied: psutil in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (5.9.4)
# Requirement already satisfied: backcall in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (3.0.32)
# Requirement already satisfied: pygments>=2.4.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (2.13.0)
# Requirement already satisfied: stack-data in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: pexpect>4.3 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: wcwidth in /Users/amani/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab->-r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: entrypoints in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r requirements.txt (line 7)) (2.5.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: rfc3339-validator in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: fqdn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: isoduration in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: uri-template in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 8)) (1.26.13)
# Requirement already satisfied: lark>=1.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 8)) (2.9.0.20250809)
# Requirement already satisfied: executing>=1.2.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/amani/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: pure-eval in /Users/amani/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 8)) (0.2.2)

# %%
from src.connectors.sqlserver_adventureworks import get_engine_from_env, get_sales_transactions
engine = get_engine_from_env()
sales = get_sales_transactions(engine, start_date=None)
print('sales rows:', len(sales))
sales.head()
# Out:
# sales rows: 31465
#    SalesOrderID  OrderDate    DueDate   ShipDate  Status  OnlineOrderFlag  \
# 0         75084 2014-06-30 2014-07-12 2014-07-07       5             True
# 1         75085 2014-06-30 2014-07-12 2014-07-07       5             True
# 2         75086 2014-06-30 2014-07-12 2014-07-07       5             True
# 3         75087 2014-06-30 2014-07-12 2014-07-07       5             True
# 4         75088 2014-06-30 2014-07-12 2014-07-07       5             True
#
#   SalesOrderNumber  CustomerID  TerritoryID  TotalDue
# 0          SO75084       11078            6  132.6000
# 1          SO75085       11927            1   18.7187
# 2          SO75086       28789            4    8.7848
# 3          SO75087       11794            4   38.6640
# 4          SO75088       14680            9  125.9258

# %%
# Load Azure enrichment CSVs (if present)
import pandas as pd
from pathlib import Path
w = Path('data/raw/azure/weather_daily.csv')
if w.exists():
    weather = pd.read_csv(w)
    print('weather rows:', len(weather))
    display(weather.head())
else:
    print('No weather file found at', w)
# Out:
# weather rows: 120
#    StationID   latitude   longitude  Year  Month  Day  DryBulbCelsius  \
# 0      10397  47.149757 -120.805769  2019     11    9            14.0
# 1      10397  47.149757 -120.805769  2019     11   10            12.2
# 2      10397  47.149757 -120.805769  2019     11   11            10.6
# 3      10397  47.149757 -120.805769  2019     11   12             8.3
# 4      10397  47.149757 -120.805769  2019     11   13             4.4
#
#    WetBulbFarenheit  WetBulbCelsius  DewPointFarenheit  DewPointCelsius  \
# 0                56            13.2                 55             13.0
# 1                47             8.4                 40              4.4
# 2                40             4.5                 25             -3.9
# 3                46             7.5                 44              6.7
# 4                39             3.9                 38              3.3
#
#    RelativeHumidity  WindSpeed  WindDirection
# 0                93          6            230
# 1                59          7            320
# 2                36          8            340
# 3                89         15             80
# 4                93          8             50

# %%
# Run the packaged ETL job

from src.etl.jobs.job_seed_and_ingest import run

if __name__ == "__main__":
    run()
# Out:
# Loading sales transactions...
# Loading order details...
# Loading customers...
# /Users/amani/Desktop/CV Projects Data Science/Data_Automation/src/etl/jobs/job_seed_and_ingest.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.strip()
# Merging header + details...
# Weather columns: ['StationID', 'latitude', 'longitude', 'Year', 'Month', 'Day', 'DryBulbCelsius', 'WetBulbFarenheit', 'WetBulbCelsius', 'DewPointFarenheit', 'DewPointCelsius', 'RelativeHumidity', 'WindSpeed', 'WindDirection']
# Wrote data/analytics/analytics_ready.csv

# %% [markdown]
# ## Next steps
#
# - Connect `data/analytics/analytics_ready.csv` to Power BI and design dashboards.
# - Add data quality checks (Great Expectations) and scheduling (Airflow/Azure Functions).
